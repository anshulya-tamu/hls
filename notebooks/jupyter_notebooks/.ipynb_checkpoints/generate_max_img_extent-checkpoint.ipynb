# %%
# import all necessary libraries
import sys
import os
from datetime import datetime, timedelta
import requests as r
import numpy as np
import pandas as pd
import geopandas as gp
import matplotlib.pyplot as plt
import random
from osgeo import gdal
import re
from tqdm import tqdm
import shutil
import calendar
import math
import joblib
import cv2

import rasterio as rio
from rasterio.mask import mask
from rasterio.enums import Resampling
from rasterio.shutil import copy
from rasterio.plot import show
from rasterio.warp import calculate_default_transform, reproject, Resampling
from rasterio.transform import Affine
from rasterio.merge import merge

import pyproj
from pyproj import Proj

from shapely.ops import transform
from shapely.geometry import Polygon

import time

from cartopy import crs
# import hvplot.xarray
# import holoviews as hv
# gv.extension('bokeh', 'matplotlib')

from multiprocessing.pool import ThreadPool
import concurrent.futures

# %%
def preprocess_reservoir_shp(fname):
  reservoirs = gp.read_file(fname)

  reservoirs.loc[31,'new_name'] = 'FARMER_S CREEK RESERVOIR'
  reservoirs.loc[106,'new_name'] = 'LAKE O THE PINES'

  t = ['/' in s for s in reservoirs['new_name']]
  i = 0
  res_names = ['COX LAKE','EAGLE NEST LAKE_MANOR LAKE','LAKE BALLINGER_LAKE MOONEN','LAKE OLNEY_LAKE COOPER','LAKE WINTERS_NEW LAKE WINTERS','MUSTANG LAKE']
  for res_idx in [23, 28, 56, 107, 129, 141]:
    reservoirs.loc[res_idx, 'new_name'] = res_names[i]
    i = i + 1

  i = 0
  res_names = ['LAKE GONZALES','CLEAR LAKE WA','CLEAR LAKE OR']
  for res_idx in [84, 388, 389]:
    reservoirs.loc[res_idx, 'new_name'] = res_names[i]
    i = i + 1

  for i in range(432):
    string = reservoirs.loc[i, 'new_name']
    regex = re.compile('[@!#$%^&*()<>?/\|}{~]')
    # Pass the string in search
    # method of regex object.
    if(regex.search(string) == None):
      continue
    else:
      print(i,string)

  return reservoirs

# %%
## Get reservoir shapefile and geometry
fname = 'WT_432.geojson'
reservoirs = preprocess_reservoir_shp(fname)

# %%
S30_x = []
S30_y = []
L30_x = []
L30_y = []

columns = ['file', 'sat', 's30_x', 's30_y', 'l30_x', 'l30_y']
df = pd.DataFrame(columns=columns)

for res_idx in [383]:
    folders = [os.path.join(str(res_idx),'clipped_rasters',d) for d in os.listdir(os.path.join(str(res_idx),'clipped_rasters'))]
    for f in folders:
        sat = [s for s in os.listdir(f) if os.path.isdir(os.path.join(f,s))]
        try:
            for s in sat:
                if s=='S30':
                    ras_data = rio.open(os.path.join(f,s,'B04_stitched_raster.tif')).read(1).astype('float')
                    new_row = pd.DataFrame({
                        'file': f,
                        'sat': s,
                        's30_x': ras_data.shape[0],
                        's30_y': ras_data.shape[1],
                        'l30_x': np.nan,
                        'l30_y': np.nan,
                    }, index=[0])
                    df = pd.concat([df,new_row],ignore_index=True)
                if s=='L30':
                    ras_data = rio.open(os.path.join(f,s,'B04_stitched_raster.tif')).read(1).astype('float')
                    new_row = pd.DataFrame({
                        'file': f,
                        'sat': s,
                        'l30_x': ras_data.shape[0],
                        'l30_y': ras_data.shape[1],
                        's30_x': np.nan,
                        's30_y': np.nan,
                    }, index=[0])
                    df = pd.concat([df,new_row],ignore_index=True)
        except BaseException as error:
            print('An exception occurred: {}'.format(error))
# Out:
# An exception occurred: 383/clipped_rasters/2022152/S30/B04_stitched_raster.tif: No such file or directory
# An exception occurred: 383/clipped_rasters/2022105/L30/B04_stitched_raster.tif: No such file or directory
# An exception occurred: 383/clipped_rasters/2020363/S30/B04_stitched_raster.tif: No such file or directory
# An exception occurred: 383/clipped_rasters/2022157/S30/B04_stitched_raster.tif: No such file or directory
# An exception occurred: 383/clipped_rasters/2021355/S30/B04_stitched_raster.tif: No such file or directory
# An exception occurred: 383/clipped_rasters/2022073/L30/B04_stitched_raster.tif: No such file or directory
# An exception occurred: 383/clipped_rasters/2022102/S30/B04_stitched_raster.tif: No such file or directory
# An exception occurred: 383/clipped_rasters/2022132/S30/B04_stitched_raster.tif: No such file or directory
# An exception occurred: 383/clipped_rasters/2019348/S30/B04_stitched_raster.tif: No such file or directory
# An exception occurred: 383/clipped_rasters/2022077/S30/B04_stitched_raster.tif: No such file or directory
# An exception occurred: 383/clipped_rasters/2021362/S30/B04_stitched_raster.tif: No such file or directory
# An exception occurred: 383/clipped_rasters/2022169/L30/B04_stitched_raster.tif: No such file or directory
# An exception occurred: 383/clipped_rasters/2021307/S30/B04_stitched_raster.tif: No such file or directory
# An exception occurred: 383/clipped_rasters/2019323/S30/B04_stitched_raster.tif: No such file or directory
# An exception occurred: 383/clipped_rasters/2022147/S30/B04_stitched_raster.tif: No such file or directory
# An exception occurred: 383/clipped_rasters/2022161/L30/B04_stitched_raster.tif: No such file or directory
# An exception occurred: 383/clipped_rasters/2019338/S30/B04_stitched_raster.tif: No such file or directory
# An exception occurred: 383/clipped_rasters/2022089/L30/B04_stitched_raster.tif: No such file or directory
# An exception occurred: 383/clipped_rasters/2022122/S30/B04_stitched_raster.tif: No such file or directory
# An exception occurred: 383/clipped_rasters/2022082/S30/B04_stitched_raster.tif: No such file or directory
# An exception occurred: 383/clipped_rasters/2021072/S30/B04_stitched_raster.tif: No such file or directory
# An exception occurred: 383/clipped_rasters/2022092/S30/B04_stitched_raster.tif: No such file or directory
# An exception occurred: 383/clipped_rasters/2022137/L30/B04_stitched_raster.tif: No such file or directory
# An exception occurred: 383/clipped_rasters/2022081/L30/B04_stitched_raster.tif: No such file or directory
# An exception occurred: 383/clipped_rasters/2022097/S30/B04_stitched_raster.tif: No such file or directory
# An exception occurred: 383/clipped_rasters/2022162/S30/B04_stitched_raster.tif: No such file or directory
# An exception occurred: 383/clipped_rasters/2022167/S30/B04_stitched_raster.tif: No such file or directory
# An exception occurred: 383/clipped_rasters/2022112/S30/B04_stitched_raster.tif: No such file or directory
# An exception occurred: 383/clipped_rasters/2022117/S30/B04_stitched_raster.tif: No such file or directory
# An exception occurred: 383/clipped_rasters/2020193/S30/B04_stitched_raster.tif: No such file or directory
# An exception occurred: 383/clipped_rasters/2021027/S30/B04_stitched_raster.tif: No such file or directory
# An exception occurred: 383/clipped_rasters/2019360/L30/B04_stitched_raster.tif: No such file or directory
# An exception occurred: 383/clipped_rasters/2022127/S30/B04_stitched_raster.tif: No such file or directory
# An exception occurred: 383/clipped_rasters/2020001/S30/B04_stitched_raster.tif: No such file or directory
# An exception occurred: 383/clipped_rasters/2022087/S30/B04_stitched_raster.tif: No such file or directory

# %%
df
# Out:
#                             file  sat s30_x s30_y l30_x l30_y
# 0    383/clipped_rasters/2019246  S30  1945  3229   NaN   NaN
# 1    383/clipped_rasters/2019243  S30  1982  3290   NaN   NaN
# 2    383/clipped_rasters/2019128  S30  1982  3290   NaN   NaN
# 3    383/clipped_rasters/2018231  S30  1970  3269   NaN   NaN
# 4    383/clipped_rasters/2019344  L30   NaN   NaN  1945  3229
# ..                           ...  ...   ...   ...   ...   ...
# 952  383/clipped_rasters/2019148  S30  1945  2899   NaN   NaN
# 953  383/clipped_rasters/2019145  L30   NaN   NaN  1970  2935
# 954  383/clipped_rasters/2020008  S30  1945  2899   NaN   NaN
# 955  383/clipped_rasters/2016009  L30   NaN   NaN  1945  2899
# 956  383/clipped_rasters/2020358  S30  1945  2899   NaN   NaN
#
# [957 rows x 6 columns]

# %% [markdown]
# ## Sentinel raster sizes

# %%
# Initialize an empty figure
fig = plt.figure(figsize=(15, 10))
k = 0
for x in df['s30_x'].unique():
    for y in df['s30_y'].unique():
        df_ = df[(df['s30_x']==x)&(df['s30_y']==y)]
        if not df_.empty:
            ax = fig.add_subplot(5, 5, k + 1)
            ras = rio.open(os.path.join(df_.iloc[0,0],df_.iloc[0,1],'B04_stitched_raster.tif'))
            show(ras, ax=ax)
            ax.set_title('{}, {}'.format(x,y))
            ax.set_xlabel(df_.iloc[0,0])
            k = k + 1
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Landsat raster sizes

# %%
# Initialize an empty figure
fig = plt.figure(figsize=(15, 10))
k = 0
for x in df['l30_x'].unique():
    for y in df['l30_y'].unique():
        df_ = df[(df['l30_x']==x)&(df['l30_y']==y)]
        if not df_.empty:
            ax = fig.add_subplot(5, 5, k + 1)
            ras = rio.open(os.path.join(df_.iloc[0,0],df_.iloc[0,1],'B04_stitched_raster.tif'))
            show(ras, ax=ax)
            ax.set_title('{}, {}'.format(x,y))
            ax.set_xlabel(df_.iloc[0,0])
            k = k + 1
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Pad smaller rasters (test)

# %%
def pad_raster(larger_raster_path, smaller_raster_path, padded_raster_path):
    """
    Pads the smaller raster to match the size of the larger raster.
    
    Parameters:
    - larger_raster_path: Path to the larger raster file.
    - smaller_raster_path: Path to the smaller raster file.
    - padded_raster_path: Path to save the padded raster.
    """
    
    with rio.open(larger_raster_path) as larger_raster:
        with rio.open(smaller_raster_path) as smaller_raster:
            
            # Extract pixel resolution from the raster's transform
            pixel_resolution_x = abs(smaller_raster.transform[0])
            pixel_resolution_y = abs(smaller_raster.transform[4])

            # Calculate the difference in extents
            left_diff = int((smaller_raster.bounds.left - larger_raster.bounds.left) / pixel_resolution_x)
            right_diff = int((larger_raster.bounds.right - smaller_raster.bounds.right) / pixel_resolution_x)
            top_diff = int((larger_raster.bounds.top - smaller_raster.bounds.top) / pixel_resolution_y)
            bottom_diff = int((smaller_raster.bounds.bottom - larger_raster.bounds.bottom) / pixel_resolution_y)
            
            # Read the smaller raster data
            smaller_data = smaller_raster.read(1)
            
            # Pad the smaller raster data
            padded_data = np.pad(smaller_data, ((top_diff, bottom_diff), (left_diff, right_diff)), 'constant', constant_values=-9999)
            
            # Create a new raster with the padded data and the same metadata as the larger raster
            with rio.open(padded_raster_path, 'w', **larger_raster.meta) as dst:
                dst.write(padded_data, 1)

# %%
pad_raster('383/clipped_rasters/2019243/S30/B04_stitched_raster.tif', '383/clipped_rasters/2017091/S30/B04_stitched_raster.tif', 'test.tif')

# %%
fig, ax = plt.subplots()
show(rio.open('test.tif'), ax = ax)
show(rio.open('383/clipped_rasters/2022112/L30/B04_stitched_raster.tif'), ax = ax, alpha=0.5)
plt.show()

# %% [markdown]
# ## Make maximum extent dataframe

# %%
df['pixel_area_l30'] = df['l30_x']*df['l30_y']
df['pixel_area_s30'] = df['s30_x']*df['s30_y']
df
# Out:
#                             file  sat s30_x s30_y l30_x l30_y pixel_area_l30  \
# 0    383/clipped_rasters/2019246  S30  1945  3229   NaN   NaN            NaN
# 1    383/clipped_rasters/2019243  S30  1982  3290   NaN   NaN            NaN
# 2    383/clipped_rasters/2019128  S30  1982  3290   NaN   NaN            NaN
# 3    383/clipped_rasters/2018231  S30  1970  3269   NaN   NaN            NaN
# 4    383/clipped_rasters/2019344  L30   NaN   NaN  1945  3229        6280405
# ..                           ...  ...   ...   ...   ...   ...            ...
# 952  383/clipped_rasters/2019148  S30  1945  2899   NaN   NaN            NaN
# 953  383/clipped_rasters/2019145  L30   NaN   NaN  1970  2935        5781950
# 954  383/clipped_rasters/2020008  S30  1945  2899   NaN   NaN            NaN
# 955  383/clipped_rasters/2016009  L30   NaN   NaN  1945  2899        5638555
# 956  383/clipped_rasters/2020358  S30  1945  2899   NaN   NaN            NaN
#
#     pixel_area_s30
# 0          6280405
# 1          6520780
# 2          6520780
# 3          6439930
# 4              NaN
# ..             ...
# 952        5638555
# 953            NaN
# 954        5638555
# 955            NaN
# 956        5638555
#
# [957 rows x 8 columns]

# %%
df['pixel_area_l30'] = df['pixel_area_l30'].astype('float')
df['pixel_area_s30'] = df['pixel_area_s30'].astype('float')

# %%
df.loc[df['pixel_area_l30'].idxmax()]['file']
# Out:
# '383/clipped_rasters/2022112'

# %%
df.loc[df['pixel_area_s30'].idxmax()]['file']
# Out:
# '383/clipped_rasters/2019243'

# %%
# Check if the file exists
if os.path.exists('max_img_extent.csv'):
    # Load the CSV file into the DataFrame
    extent_df = pd.read_csv('max_img_extent.csv')
else:
    # Create an empty DataFrame with the specified columns
    columns = ['res_idx', 'L30_x', 'L30_y', 'S30_x', 'S30_y', 'l_file', 's_file']
    extent_df = pd.DataFrame(columns=columns)
extent_df
# Out:
# Empty DataFrame
# Columns: [res_idx, L30_x, L30_y, S30_x, S30_y, l_file, s_file]
# Index: []

# %%
new_row = pd.DataFrame({
    'res_idx': res_idx, 
    'L30_x': df.loc[df['pixel_area_l30'].idxmax()]['l30_x'], 
    'L30_y': df.loc[df['pixel_area_l30'].idxmax()]['l30_y'], 
    'S30_x': df.loc[df['pixel_area_s30'].idxmax()]['s30_x'], 
    'S30_y': df.loc[df['pixel_area_s30'].idxmax()]['s30_y'], 
    'l_file': df.loc[df['pixel_area_l30'].idxmax()]['file'], 
    's_file': df.loc[df['pixel_area_s30'].idxmax()]['file']
},index=[0])

extent_df = pd.concat([extent_df, new_row], ignore_index=True)

# %%
extent_df
# Out:
#   res_idx L30_x L30_y S30_x S30_y                       l_file  \
# 0     383  1982  3290  1982  3290  383/clipped_rasters/2022112
#
#                         s_file
# 0  383/clipped_rasters/2019243

# %%
extent_df.to_csv('max_img_extent.csv')
